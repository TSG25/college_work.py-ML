# %%
import pandas as pd

# %%
data= pd.read_csv("athlete_events.csv")

# %%
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data.tail(10)
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 271106  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566    James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
# 271111  135569                    Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                      Piotr ya   M  27.0   176.0    59.0
# 271113  135570                      Piotr ya   M  27.0   176.0    59.0
# 271114  135571            Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571            Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 271106      Argentina  ARG  2004 Summer  2004  Summer          Athina
# ...

# %%
data.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %%
data.Sex
# Out:
# 0         M
# 1         M
# 2         M
# 3         M
# 4         F
#          ..
# 271111    M
# 271112    M
# 271113    M
# 271114    M
# 271115    M
# Name: Sex, Length: 271116, dtype: object

# %%
data["Sex"]
# Out:
# 0         M
# 1         M
# 2         M
# 3         M
# 4         F
#          ..
# 271111    M
# 271112    M
# 271113    M
# 271114    M
# 271115    M
# Name: Sex, Length: 271116, dtype: object

# %%
data[['Sex','Name','NOC']]
# Out:
#        Sex                      Name  NOC
# 0        M                 A Dijiang  CHN
# 1        M                  A Lamusi  CHN
# 2        M       Gunnar Nielsen Aaby  DEN
# 3        M      Edgar Lindenau Aabye  DEN
# 4        F  Christine Jacoba Aaftink  NED
# ...     ..                       ...  ...
# 271111   M                Andrzej ya  POL
# 271112   M                  Piotr ya  POL
# 271113   M                  Piotr ya  POL
# 271114   M        Tomasz Ireneusz ya  POL
# 271115   M        Tomasz Ireneusz ya  POL
#
# [271116 rows x 3 columns]

# %%
data.shape
# Out:
# (271116, 15)

# %%
print(data.shape[0])
data.shape[1]
# Out:
# 271116
# 15

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
data.value_counts()
# Out:
# ID      Name                       Sex  Age   Height  Weight  Team          NOC  Games        Year  Season  City         Sport       Event                                     Medal
# 16      Juhamatti Tapio Aaltonen   M    28.0  184.0   85.0    Finland       FIN  2014 Winter  2014  Winter  Sochi        Ice Hockey  Ice Hockey Men's Ice Hockey               Bronze    1
# 93076   Erkki Eino Antero Penttil  M    24.0  167.0   66.0    Finland       FIN  1956 Summer  1956  Summer  Melbourne    Wrestling   Wrestling Men's Featherweight, Freestyle  Bronze    1
# 93134   Oribe Peralta Morones      M    28.0  179.0   73.0    Mexico        MEX  2012 Summer  2012  Summer  London       Football    Football Men's Football                   Gold      1
# 93119   Alfio Peraboni             M    30.0  195.0   130.0   Italy         ITA  1984 Summer  1984  Summer  Los Angeles  Sailing     Sailing Mixed Two Person Keelboat         Bronze    1
# ...

# %%
data.Name.value_counts()
# Out:
# Name
# Robert Tait McKenzie            58
# Heikki Ilmari Savolainen        39
# Joseph "Josy" Stoffel           38
# Ioannis Theofilakis             36
# Takashi Ono                     33
#                                 ..
# Tatyana Vasilyevna Kalmykova     1
# Mariya Lvovna Kalmykova          1
# Christine Kalmer                 1
# Joannis "Jannis" Kalmazidis      1
# Pierre-Georges LeClercq          1
# Name: count, Length: 134732, dtype: int64

# %%
data.Sex.value_counts(ascending=True)
# Out:
# Sex
# F     74522
# M    196594
# Name: count, dtype: int64

# %%
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data["NOC"]
# Out:
# 0         CHN
# 1         CHN
# 2         DEN
# 3         DEN
# 4         NED
#          ...
# 271111    POL
# 271112    POL
# 271113    POL
# 271114    POL
# 271115    POL
# Name: NOC, Length: 271116, dtype: object

# %%
data.NOC
# Out:
# 0         CHN
# 1         CHN
# 2         DEN
# 3         DEN
# 4         NED
#          ...
# 271111    POL
# 271112    POL
# 271113    POL
# 271114    POL
# 271115    POL
# Name: NOC, Length: 271116, dtype: object

# %%
type(data.Age)
# Out:
# pandas.core.series.Series

# %%
data[['Team','NOC','Games','Year']]
# Out:
#                   Team  NOC        Games  Year
# 0                China  CHN  1992 Summer  1992
# 1                China  CHN  2012 Summer  2012
# 2              Denmark  DEN  1920 Summer  1920
# 3       Denmark/Sweden  DEN  1900 Summer  1900
# 4          Netherlands  NED  1988 Winter  1988
# ...                ...  ...          ...   ...
# 271111        Poland-1  POL  1976 Winter  1976
# 271112          Poland  POL  2014 Winter  2014
# 271113          Poland  POL  2014 Winter  2014
# 271114          Poland  POL  1998 Winter  1998
# 271115          Poland  POL  2002 Winter  2002
#
# [271116 rows x 4 columns]

# %%
type(data[['Team','NOC','Games','Year']])
# Out:
# pandas.core.frame.DataFrame

# %%
data.NOC
# Out:
# 0         CHN
# 1         CHN
# 2         DEN
# 3         DEN
# 4         NED
#          ...
# 271111    POL
# 271112    POL
# 271113    POL
# 271114    POL
# 271115    POL
# Name: NOC, Length: 271116, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df2 =data[data.Year==1996]
df2.sort_values('Name').head(10)
# Out:
#             ID                                     Name Sex   Age  Height  \
# 68346    34903  A. J. Tyronne Benildus "Benny" Fernando   M  27.0   179.0
# 108799   55026                          Aa Bela Joaquim   F  29.0     NaN
# 69436    35386                 Aadjijatmiko Finarsih H.   F  24.0     NaN
# 154614   77625                      Aaron John McIntosh   M  24.0   177.0
# 252498  126445                          Aart Vierhouten   M  26.0   182.0
# 3426      1939                           Abbas Al-Harbi   M  28.0     NaN
# 115833   58673                         Abbas Haj Kenari   M  22.0   170.0
# 105306   53277                             Abbas Jadidi   M  27.0   185.0
# 3727      2138                        Abdalla Al-Sebaei   M  20.0     NaN
# 26987    14036                      Abdel Aziz Boulehia   M  25.0   170.0
#
#         Weight         Team  NOC        Games  Year  Season     City  \
# 68346     70.0    Sri Lanka  SRI  1996 Summer  1996  Summer  Atlanta
# ...

# %%
dt =data[(data.Medal=="Gold") & (data.Sex =="M") & (data.Sport =="Cycling") & (data.Year ==2004)]
dt.sort_values(by='Name',ascending=False)
# Out:
#             ID                              Name Sex   Age  Height  Weight  \
# 265396  132807  Vyacheslav Vladimirovich Yekimov   M  38.0   175.0    67.0
# 175348   88124              Stuart Peter O'Grady   M  31.0   177.0    71.0
# 262941  131571          Stephen Brian Wooldridge   M  26.0   186.0    78.0
# 172031   86438                      Stefan Nimke   M  26.0   186.0    94.0
# 16607     8910               Ryan Neville Bayley   M  22.0   182.0    90.0
# 16608     8910               Ryan Neville Bayley   M  22.0   182.0    90.0
# 262509  131345                         Ren Wolff   M  26.0   179.0    75.0
# 50115    25796              Peter Douglas Dawson   M  22.0   182.0    74.0
# 20963    11069                     Paolo Bettini   M  30.0   169.0    58.0
# 102221   51710       Mikhail Borisovich Ignatyev   M  19.0   176.0    67.0
# 201711  101311               Luke Justin Roberts   M  27.0   181.0    71.0
# ...

# %%
data[(data.Sex =="M") & (data.Sport =="Cycling")]
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 149         56                       Ren Abadie   M  21.0     NaN     NaN
# 150         56                       Ren Abadie   M  21.0     NaN     NaN
# 152         58                 Georgi Abadzhiev   M   NaN     NaN     NaN
# 153         58                 Georgi Abadzhiev   M   NaN     NaN     NaN
# 242        118                    Mahmoud Abbas   M  22.0   165.0    65.0
# ...        ...                              ...  ..   ...     ...     ...
# 270767  135411                        Alex Zlle   M  32.0   185.0    72.0
# 270800  135430                     Zundui Naran   M  25.0     NaN     NaN
# 271003  135515     Adriaan "Adrie" Zwartepoorte   M  19.0     NaN     NaN
# 271075  135552  Jan (Johann-) Zybert (Siebert-)   M  20.0     NaN     NaN
# 271101  135562                       Milan Zyka   M  24.0   173.0    68.0
#
#                   Team  NOC        Games  Year  Season       City    Sport  \
# ...

# %%
data.Sport.value_counts()
# Out:
# Sport
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10859
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: count, Length: 66, dtype: int64

# %%
data[(data.Year>=1984) &(data.Year<=1994)]
data.NOC.value_counts().head(3)
# Out:
# NOC
# USA    18853
# FRA    12758
# GBR    12256
# Name: count, dtype: int64

# %%
gdh =data[(data.Medal=='Gold')&(data.Sex=='M')&(data.Event=="Basketball Men's Basketball")]

# %%
gdh.sort_values('Year',ascending=False)
gdh[['Name','Age','Team','NOC']].sort_values('Age').head(5)
# Out:
#                                       Name   Age           Team  NOC
# 49805           Anthony Marshon Davis, Jr.  19.0  United States  USA
# 4623           Stephen Todd "Steve" Alford  19.0  United States  USA
# 56093   Terence Gilbert "Terry" Dischinger  19.0  United States  USA
# 92557                      Spencer Haywood  19.0  United States  USA
# 100183      Phillip Gregory "Phil" Hubbard  19.0  United States  USA
