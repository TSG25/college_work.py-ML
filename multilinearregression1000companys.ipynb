# %% [markdown]
# <a href="https://colab.research.google.com/github/TSG25/college_work.py-ML/blob/main/multilinearregression1000companys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Multilinear regressions**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/1000_Companies.csv")
df
# Out:
#      R&D Spend  Administration  Marketing Spend       State        Profit
# 0    165349.20      136897.800      471784.1000    New York  192261.83000
# 1    162597.70      151377.590      443898.5300  California  191792.06000
# 2    153441.51      101145.550      407934.5400     Florida  191050.39000
# 3    144372.41      118671.850      383199.6200    New York  182901.99000
# 4    142107.34       91391.770      366168.4200     Florida  166187.94000
# ..         ...             ...              ...         ...           ...
# 995   54135.00      118451.999      173232.6695  California   95279.96251
# 996  134970.00      130390.080      329204.0228  California  164336.60550
# 997  100275.47      241926.310      227142.8200  California  413956.48000
# 998  128456.23      321652.140      281692.3200  California  333962.19000
# 999  161181.72      270939.860      295442.1700    New York  476485.43000
#
# [1000 rows x 5 columns]

# %%
x = df.drop("Profit", axis= 1)
y = df.iloc[:, 4].values

# %%
x

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-47-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# 1 dataset collection
# 2 reading
# 3 heatmap
# 4 indentify(categorical data)
# 5one - hot encoding
# 6splt data
# 7model training
# 8prediction
# 9model matrics

# %%
dummie = pd.get_dummies(df["State"])
dummie
# Out:
#      California  Florida  New York
# 0             0        0         1
# 1             1        0         0
# 2             0        1         0
# 3             0        0         1
# 4             0        1         0
# ..          ...      ...       ...
# 995           1        0         0
# 996           1        0         0
# 997           1        0         0
# 998           1        0         0
# 999           0        0         1
#
# [1000 rows x 3 columns]

# %%
merge = pd.concat([x,dummie], axis = 1)
merge
# Out:
#      R&D Spend  Administration  Marketing Spend       State  California  \
# 0    165349.20      136897.800      471784.1000    New York           0
# 1    162597.70      151377.590      443898.5300  California           1
# 2    153441.51      101145.550      407934.5400     Florida           0
# 3    144372.41      118671.850      383199.6200    New York           0
# 4    142107.34       91391.770      366168.4200     Florida           0
# ..         ...             ...              ...         ...         ...
# 995   54135.00      118451.999      173232.6695  California           1
# 996  134970.00      130390.080      329204.0228  California           1
# 997  100275.47      241926.310      227142.8200  California           1
# 998  128456.23      321652.140      281692.3200  California           1
# 999  161181.72      270939.860      295442.1700    New York           0
#
#      Florida  New York
# 0          0         1
# 1          0         0
# 2          1         0
# ...

# %%
final = merge.drop(['State','New York'], axis =1)

# %%
final
# Out:
#      R&D Spend  Administration  Marketing Spend  California  Florida
# 0    165349.20      136897.800      471784.1000           0        0
# 1    162597.70      151377.590      443898.5300           1        0
# 2    153441.51      101145.550      407934.5400           0        1
# 3    144372.41      118671.850      383199.6200           0        0
# 4    142107.34       91391.770      366168.4200           0        1
# ..         ...             ...              ...         ...      ...
# 995   54135.00      118451.999      173232.6695           1        0
# 996  134970.00      130390.080      329204.0228           1        0
# 997  100275.47      241926.310      227142.8200           1        0
# 998  128456.23      321652.140      281692.3200           1        0
# 999  161181.72      270939.860      295442.1700           0        0
#
# [1000 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train ,y_test = train_test_split(final,y,test_size=0.2)

# %%
x_train
# Out:
#      R&D Spend  Administration  Marketing Spend  California  Florida
# 44    22177.74     154806.1400       28334.7200           1        0
# 718  129228.00     129542.0753      318124.8181           0        0
# 932  107094.00     126273.2253      275417.2046           1        0
# 655  147647.00     132262.2771      353664.3289           0        1
# 417   36345.00     115824.6907      138906.8159           1        0
# ..         ...             ...              ...         ...      ...
# 429   96720.00     124741.1458      255400.5433           1        0
# 514  105004.00     125964.5646      271384.5439           0        1
# 589   19242.00     113298.8418      105906.5307           0        0
# 620  148420.00     132376.4373      355155.8345           1        0
# 220   19870.00     113391.5877      107118.2584           0        0
#
# [800 rows x 5 columns]

# %%
y_train

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_train)

# %%
model.score(x_test, y_test)
# Out:
# 0.9108241441746291

# %%
data = pd.read_csv("/content/Student_Performance.csv")

# %%
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
x = data.drop("Performance Index", axis= 1)

# %%
y = data.iloc[:, 5].values

# %%
y
# Out:
# array([91., 65., 45., ..., 74., 95., 64.])

# %%
sns.heatmap(data.corr())
# Out:
# <ipython-input-98-8b96879b4d02>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <Axes: >

# %%
data.head(3)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0

# %%
dummie = pd.get_dummies(data["Extracurricular Activities"])
dummie
# Out:
#       No  Yes
# 0      0    1
# 1      1    0
# 2      0    1
# 3      0    1
# 4      1    0
# ...   ..  ...
# 9995   0    1
# 9996   0    1
# 9997   0    1
# 9998   0    1
# 9999   1    0
#
# [10000 rows x 2 columns]

# %%
merge = pd.concat([x,dummie], axis = 1)
merge
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
final_data =merge.drop(['Extracurricular Activities',"No"], axis = 1)

# %%
final_data
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Yes
# 0                                    1    1
# 1                                    2    0
# 2                                    2    1
# 3                                    2    1
# 4                                    5    0
# ...                                ...  ...
# 9995                                 2    1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train ,y_test = train_test_split(final_data,y,test_size=0.2)

# %%
x_train
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 9404              9               77            9
# 7031              6               76            6
# 7890              5               60            9
# 785               6               96            8
# 4188              3               61            5
# ...             ...              ...          ...
# 7323              4               83            5
# 6989              6               71            9
# 8789              9               60            5
# 9283              9               98            4
# 8131              8               48            9
#
#       Sample Question Papers Practiced  Yes
# 9404                                 8    1
# 7031                                 4    0
# 7890                                 3    1
# 785                                  9    0
# 4188                                 2    1
# ...                                ...  ...
# 7323                                 3    0
# ...

# %%
from sklearn.linear_model import LinearRegression
model_lr = LinearRegression()

# %%
model_lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model_lr.predict(x_train)
# Out:
# array([76.57485954, 64.12025004, 46.83248931, ..., 55.90077475,
#        93.53017179, 43.15544024])

# %%
model_lr.score(x_test, y_test)
# Out:
# 0.9888073499667357
